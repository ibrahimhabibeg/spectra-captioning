# %%
import pandas as pd

df = pd.read_parquet("../data/crossmatch_cache/crossmatch_merged_1.0arcsec.parquet")
df.head()
# Out:
#           Z  _dist_arcsec        _healpix_29 additional_names  \
# 0  0.893283      0.257587     56333355682100               []
# 1  0.568009      0.317206     56334824474469               []
# 2  0.568009      0.317206     56334824474469          [J0300]
# 3  0.568009      0.185631     56334824881092               []
# 4  0.218987      0.131972  37031847698858078         [021348]
#
#            arxiv_id coordinate_resolution_name  dec_mentions  dec_spectra  \
# 0  astro-ph/0611120                  0259+0048      0.803780     0.803780
# 1        2203.11964   SDSS J030000.57+004828.0      0.807752     0.807797
# 2        2402.10581   SDSS J030000.56+004828.0      0.807752     0.807797
# 3        1507.07247        J030000.57+004828.0      0.807780     0.807797
# 4        1911.07854             021348 (J0213)     12.997640    12.997660
#
#      discussion_extent  evidence_quote_count  ... ra_mentions ra_spectra  \
# ...

# %%
df['object_id'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df['object_id'].astype(int)
#
# File ~/Desktop/development/spectra-captioning/.venv/lib/python3.13/site-packages/pandas/core/generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6661             ]
#    6662
#    6663         else:
#    6664             # else, only a single dtype is given
# -> 6665             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667             return res.__finalize__(self, method="astype")
#    6668
#
# File ~/Desktop/development/spectra-captioning/.venv/lib/python3.13/site-packages/pandas/core/internals/managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
#     447     copy = False
# ...

# %%
df[df['object_id'] == '39632951360620188']
# Out:
#              Z  _dist_arcsec         _healpix_29 additional_names    arxiv_id  \
# 4575  0.197513      0.133871  643592388338055503               []  2207.01648
#
#      coordinate_resolution_name  dec_mentions  dec_spectra discussion_extent  \
# 4575    2MASX J14344537+3328211     33.472399     33.47238   short_paragraph
#
#       evidence_quote_count  ... ra_mentions  ra_spectra  \
# 4575                     1  ...  218.688998  218.688959
#
#      resolver_agent_confidence resolver_api_or_agent resolver_method_used  \
# 4575                    medium              subagent  resolved_from_paper
#
#                                                spectrum  \
# 4575  {'flux': [-13.777952, 18.727985, 16.35055, 1.0...
#
#                                               uat_terms wiki_entity_id survey  \
# 4575  [Giant radio galaxies, Fanaroff-Riley radio ga...   gmw_00006565   desi
#
#                                         survey_metadata
# ...

# %%
df[df['survey'] == 'desi']['_healpix_29'].nunique()
# Out:
# 361
